# %%
# environment manipulation
from pathlib import Path
from os import listdir
from os.path import isfile, join
import glob

# other 
import time


# ml libraries
import numpy as np
import pandas as pd
import tensorflow as tf


# import brainflow
# from brainflow.board_shim import BoardShim, BrainFlowInputParams, BoardIds
# from brainflow.data_filter import DataFilter, FilterTypes, AggOperations


# from keras.models import Model
# from keras.layers import Input
# from keras.layers import Dense

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step into main directory for data
    # Set up environmental variables
    # Step into sub directory (Directional CMD)
        # copy into a numpy (directioncmd_time stamp)

path = glob.glob('../TrimmedData/*')
folder_array = []
concat_numpys = []
count = 0

for folder in path:
    folder_array.append(folder)
    # we're in, now set up environmental variables:
    inner_path = glob.glob(folder)
    arrays = []
    for f in inner_path: 
        arrays.append(np.loadtxt(f, delimiter=','))
    concat_numpys[count] = np.concatenate(arrays)
    # np.savetxt(f"{folder}.npy", concat_numpys, delimiter=',')     # <--- check visualization for how to import this
    np.save(f"{folder}_.npy", concat_numpys[count])                         # <--- a lil easier to import, me no care for delimiters
    count = count + 1
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /var/folders/zb/3vrl7dx522779k0c5nycljx00000gn/T/ipykernel_35278/3716498141.py in <module>
#      15     arrays = []
#      16     for f in inner_path:
# ---> 17         arrays.append(np.loadtxt(f, delimiter=','))
#      18     concat_numpys[count] = np.concatenate(arrays)
#      19     # np.savetxt(f"{folder}.npy", concat_numpys, delimiter=',')     # <--- check visualization for how to import this
#
# /opt/homebrew/Caskroom/miniforge/base/envs/ml_env/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065             fname = os_fspath(fname)
#    1066         if _is_string_like(fname):
# -> 1067             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
# ...

# %%
# Step into main directory for data
    # Set up environmental variables
    # Step into sub directory (Directional CMD)
        # copy into a numpy (directioncmd.npy stamp)

path = glob.glob('../TrimmedData/*')
folder_array = []
concat_numpys = []
count = 0

for folder in path:
    # folder_array.append(folder)
    # we're in, now set up environmental variables:
    inner_path = path + glob.glob(folder)
    arrays = []
    for f in files: 
        arrays.append(np.loadtxt(f, delimiter=','))
    concat_numpys[count] = np.concatenate(arrays)
    # np.savetxt(f"{folder}.npy", concat_numpys, delimiter=',')     # <--- check visualization for how to import this
    np.save(f"{folder}_.npy", concat_numpys[count])                         # <--- a lil easier to import, me no care for delimiters
    count = count + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/zb/3vrl7dx522779k0c5nycljx00000gn/T/ipykernel_35278/1988144238.py in <module>
#      16     for f in files:
#      17         arrays.append(np.loadtxt(f, delimiter=','))
# ---> 18     concat_numpys[count] = np.concatenate(arrays)
#      19     # np.savetxt(f"{folder}.npy", concat_numpys, delimiter=',')     # <--- check visualization for how to import this
#      20     np.save(f"{folder}_.npy", concat_numpys[count])                         # <--- a lil easier to import, me no care for delimiters
#
# IndexError: list assignment index out of range

# %%
files = glob.glob('../TrimmedData/Forward' + '/*.npy')

arrays = []
for f in files:
    arrays.append(np.loadtxt(f, delimiter=','))
concat_numpys = np.concatenate(arrays)

# %%
# Prepare column names:
homemade_columns = []
for i in range(1, 9):
    num = "c" + str(i)
    homemade_columns.append(num)
    
print (homemade_columns)
# Out:
# ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8']

# %%
# put it in a dataframe
data = pd.DataFrame(concat_numpys, columns=homemade_columns)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105000 entries, 0 to 104999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   c1      105000 non-null  float64
#  1   c2      105000 non-null  float64
#  2   c3      105000 non-null  float64
#  3   c4      105000 non-null  float64
#  4   c5      105000 non-null  float64
#  5   c6      105000 non-null  float64
#  6   c7      105000 non-null  float64
#  7   c8      105000 non-null  float64
# dtypes: float64(8)
# memory usage: 6.4 MB

# %% [markdown]
# ## Backward Data Correlation

# %%
# make dataframes for the concatenated numpys
path = glob.glob('../ConcatenatedTrimmedData/*')


# import a numpy from the environment
backward_all = np.load('../ConcatenatedTrimmedData/Backward.npy')

# cast as a DataFrame
backward_all = pd.DataFrame(backward_all, columns=homemade_columns)

# Plot correlation matrix
sns.heatmap(backward_all.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Forward Data Correlation

# %%
# make dataframes for the concatenated numpys
path = glob.glob('../ConcatenatedTrimmedData/*')


# import a numpy from the environment
forward_all = np.load('../ConcatenatedTrimmedData/Forward.npy')

# cast as a DataFrame
forward_all = pd.DataFrame(forward_all, columns=homemade_columns)

# Plot correlation matrix
sns.heatmap(forward_all.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Right Data Correlation

# %%
# import a numpy from the environment
forward_all = np.load('../ConcatenatedTrimmedData/Right.npy')

# cast as a DataFrame
forward_all = pd.DataFrame(forward_all, columns=homemade_columns)

# Plot correlation matrix
sns.heatmap(forward_all.corr(), annot=True)
# Out:
# <AxesSubplot:>
